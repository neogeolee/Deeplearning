# %% [markdown]
# <a href="https://colab.research.google.com/github/neogeolee/Deeplearning/blob/master/tf07_cifar10_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2020/08/19
이름 : 이태훈
내용 : 딥러닝 cifar10 이미지 분류 실습하기
"""
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets.cifar10 import load_data
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from sklearn.model_selection import train_test_split
from PIL import Image # 파이썬 이미지 처리 라이브러리

# %%
# 학습데이터 로드
(cifar10_train_data, cifar10_train_label), (cifar10_test_data, cifar10_test_label) = load_data()

# 데이터 형태 확인
print(cifar10_train_data.shape, cifar10_train_label.shape)
print(cifar10_test_data.shape, cifar10_test_label.shape)
print(cifar10_train_label)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]

# %%
# 데이터 샘플 이미지 출력
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
random_idx = np.random.randint(50000, size=9)
print(random_idx)

plt.figure(figsize=(5, 5))

for i, idx in enumerate(random_idx):
  plt.subplot(3, 3, i+1)
  plt.xticks([])
  plt.yticks([])
  label = cifar10_train_label[idx][0]
  plt.imshow(cifar10_train_data[idx, :])
  plt.title('%s' % class_names[label])
# Out:
# [32413 12701 30200 45286 16688 32584 22285 40836 16177]

# %%
# 데이터셋 분할하기
train_data, test_data, train_label, test_label = train_test_split(cifar10_train_data, cifar10_train_label)
print('훈련데이터 : ', train_data.shape)
print('검증데이터 : ', test_data.shape)
# Out:
# 훈련데이터 :  (37500, 32, 32, 3)
# 검증데이터 :  (12500, 32, 32, 3)

# %%
# 모델학습을 위한 데이터전처리(정규화)

# 방법1 : 픽셀데이터를 0 ~ 1 사이로 초기화 하는 정규화 -> 정확도 낮음
#train_data = train_data / 255
#test_data = test_data / 255
#cifar10_test_data = cifar10_test_data / 255


# 방법2: 픽셀데이터를 평균과 표준편차를 이용한 정규화 -> 정확도 높음
mean = np.mean(train_data, axis=(0, 1, 2))
std = np.std(train_data, axis=(0, 1, 2))

train_data = (train_data - mean) / std
test_data = (test_data - mean) / std
cifar10_test_data = (cifar10_test_data - mean) / std

# 각 데이터의 레이블을 범주형(one-hot encoding) 형태로 변환
train_label = to_categorical(train_label)
test_label = to_categorical(test_label)
cifar10_test_label = to_categorical(cifar10_test_label)

# %%
# 학습모델 구성하기
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3))) # 입력층
model.add(Dense(64, activation='relu')) # 은닉층
model.add(Dense(32, activation='relu')) # 은닉층
model.add(Dense(10, activation='softmax')) # 출력층

# %%
# 학습모델 설정하기
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

# %%
# 학습하기
model.fit(train_data,
          train_label,
          epochs=30,
          batch_size=128,
          validation_data=(test_data, test_label))
# Out:
# Epoch 1/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.8235 - acc: 0.3628 - val_loss: 1.6760 - val_acc: 0.4168
# Epoch 2/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.5897 - acc: 0.4415 - val_loss: 1.6198 - val_acc: 0.4298
# Epoch 3/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.4887 - acc: 0.4747 - val_loss: 1.5627 - val_acc: 0.4561
# Epoch 4/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.4188 - acc: 0.5008 - val_loss: 1.5489 - val_acc: 0.4602
# Epoch 5/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.3704 - acc: 0.5177 - val_loss: 1.5246 - val_acc: 0.4669
# Epoch 6/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.3234 - acc: 0.5375 - val_loss: 1.5152 - val_acc: 0.4730
# Epoch 7/30
# 293/293 [==============================] - 1s 5ms/step - loss: 1.2905 - acc: 0.5452 - val_loss: 1.5209 - val_acc: 0.4719
# Epoch 8/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.2550 - acc: 0.5589 - val_loss: 1.5399 - val_acc: 0.4709
# Epoch 9/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.2258 - acc: 0.5708 - val_loss: 1.5136 - val_acc: 0.4806
# Epoch 10/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.2010 - acc: 0.5782 - val_loss: 1.5266 - val_acc: 0.4778
# Epoch 11/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.1727 - acc: 0.5879 - val_loss: 1.5328 - val_acc: 0.4802
# Epoch 12/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.1479 - acc: 0.5969 - val_loss: 1.5034 - val_acc: 0.4967
# Epoch 13/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.1297 - acc: 0.6005 - val_loss: 1.5363 - val_acc: 0.4875
# Epoch 14/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.1064 - acc: 0.6113 - val_loss: 1.5411 - val_acc: 0.4810
# Epoch 15/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.0849 - acc: 0.6201 - val_loss: 1.5458 - val_acc: 0.4918
# Epoch 16/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.0678 - acc: 0.6239 - val_loss: 1.5495 - val_acc: 0.4871
# Epoch 17/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.0514 - acc: 0.6296 - val_loss: 1.5816 - val_acc: 0.4815
# Epoch 18/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.0265 - acc: 0.6388 - val_loss: 1.6016 - val_acc: 0.4877
# Epoch 19/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.0122 - acc: 0.6422 - val_loss: 1.5875 - val_acc: 0.4853
# Epoch 20/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.9990 - acc: 0.6488 - val_loss: 1.6225 - val_acc: 0.4864
# Epoch 21/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.9839 - acc: 0.6525 - val_loss: 1.6520 - val_acc: 0.4752
# Epoch 22/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.9688 - acc: 0.6594 - val_loss: 1.6537 - val_acc: 0.4878
# Epoch 23/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.9548 - acc: 0.6634 - val_loss: 1.6579 - val_acc: 0.4803
# Epoch 24/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.9391 - acc: 0.6685 - val_loss: 1.6742 - val_acc: 0.4792
# Epoch 25/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.9233 - acc: 0.6762 - val_loss: 1.7319 - val_acc: 0.4711
# Epoch 26/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.9134 - acc: 0.6797 - val_loss: 1.6756 - val_acc: 0.4799
# Epoch 27/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.9005 - acc: 0.6820 - val_loss: 1.7018 - val_acc: 0.4837
# Epoch 28/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.8843 - acc: 0.6862 - val_loss: 1.7166 - val_acc: 0.4800
# Epoch 29/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.8670 - acc: 0.6964 - val_loss: 1.7842 - val_acc: 0.4784
# Epoch 30/30
# 293/293 [==============================] - 2s 5ms/step - loss: 0.8600 - acc: 0.6936 - val_loss: 1.7889 - val_acc: 0.4779

# %%
# 평가하기
model.evaluate(cifar10_test_data, cifar10_test_label)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 1.7855 - acc: 0.4765
# [1.7855019569396973, 0.476500004529953]

# %%
# 테스트하기
result = model.predict(cifar10_test_data)
result.round()

from sklearn.metrics import accuracy_score
score = accuracy_score(result.round(), cifar10_test_label)
print('점수 : ', score)
# Out:
# 점수 :  0.397
